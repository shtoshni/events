# %%
from allennlp.predictors.predictor import Predictor

# %%
srl_model = Predictor.from_path(
    "https://storage.googleapis.com/allennlp-public-models/bert-base-srl-2020.11.19.tar.gz")

# %%
sentence = "So, India has no right to demand my extradition if I hire a team of 40 gold smugglers and reap the rewards?"

# %%
srl_model.predict(sentence=sentence)
# Out:
# {'verbs': [{'verb': 'has',
#    'description': '[ARGM-DIS: So] , [ARG0: India] [V: has] [ARG1: no right to demand my extradition] [ARGM-ADV: if I hire a team of 40 gold smugglers and reap the rewards] ?',
#    'tags': ['B-ARGM-DIS',
#     'O',
#     'B-ARG0',
#     'B-V',
#     'B-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'B-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'I-ARGM-ADV',
#     'O']},
#   {'verb': 'demand',
#    'description': 'So , [ARG0: India] has no right to [V: demand] [ARG1: my extradition] if I hire a team of 40 gold smugglers and reap the rewards ?',
#    'tags': ['O',
#     'O',
#     'B-ARG0',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-V',
#     'B-ARG1',
#     'I-ARG1',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']},
#   {'verb': 'hire',
#    'description': 'So , India has no right to demand my extradition if [ARG0: I] [V: hire] [ARG1: a team of 40 gold smugglers] and reap the rewards ?',
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ARG0',
#     'B-V',
#     'B-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']},
#   {'verb': 'reap',
#    'description': 'So , India has no right to demand my extradition if [ARG0: I] hire a team of 40 gold smugglers and [V: reap] [ARG1: the rewards] ?',
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ARG0',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-V',
#     'B-ARG1',
#     'I-ARG1',
#     'O']}],
#  'words': ['So',
#   ',',
#   'India',
#   'has',
#   'no',
#   'right',
#   'to',
#   'demand',
#   'my',
#   'extradition',
#   'if',
#   'I',
#   'hire',
#   'a',
#   'team',
#   'of',
#   '40',
#   'gold',
#   'smugglers',
#   'and',
#   'reap',
#   'the',
#   'rewards',
#   '?']}

# %%
def try_simple_alignment(orig_words, proc_words):
    orig_idx = 0
    mapping = {}
    cur_word = ""
    for proc_idx, proc_word in enumerate(proc_words):
        if (proc_word == orig_words[orig_idx]) or ((cur_word + proc_word) == orig_words[orig_idx]):
            mapping[proc_idx] = orig_idx
            orig_idx += 1
            cur_word = ""
        elif proc_word in orig_words[orig_idx]:
            cur_word += proc_word
            mapping[proc_idx] = orig_idx
        else:
            raise ValueError(proc_word, orig_words[orig_idx], orig_words, proc_words)

    assert (orig_idx == len(orig_words))
    return mapping

# %%
def parse_output(output_dict):
    tag_dict_list = []
    for verb_dict in output_dict['verbs']:
        tags = verb_dict['tags']
        tag_to_idx = {}
        for idx, tag in enumerate(tags):
            if tag == 'O':
                continue
            else:
                begin_or_in, arg = tag[:1], tag[2:]

                if begin_or_in == 'B':
                    tag_to_idx[arg] = [idx]
                else:
                    try:
                        tag_to_idx[arg].append(idx)
                    except KeyError:
                        # The model can sometimes directly output I-ARGX instead of starting with B-ARGX
                        # Sample Sentence - "Continental Airlines Board discusses merger with United XXXXXXXX :
                        # Jump Headline Goes Herey and Herey"
                        pass

        if 'V' in tag_to_idx:
            tag_dict_list.append(tag_to_idx)
        else:
            print(verb_dict)

    return tag_dict_list

# %%
import json
from os import path
import os
from collections import OrderedDict

proc_file = "/home/shtoshni/Research/events/proc_data/kbp_2015/cleaned/dev.512.jsonlines"
output_dir = "/home/shtoshni/Research/events/proc_data/kbp_2015/srl"

if not path.exists(output_dir):
    os.makedirs(output_dir)

output_file = path.join(output_dir, path.basename(proc_file)) 

with open(proc_file) as f: #, open(output_file, "w") as writer_f:
    for line in f:
        instance = json.loads(line.strip())
        doc = []
        for sentence in instance["sentences"]:
            doc.extend(sentence)
            
        srl_info_list = []
        batch_json_list = []
        batch_sentences = []
        batch_offsets = []
        for tokenized_sentence in instance["tokenized_sentences"]:
            sentence, offsets = zip(*tokenized_sentence)
            if len(sentence) > 100:
                # Some sentences are too long!
                continue

            sentence_str = " ".join(sentence)
            batch_json_list.append({"sentence": sentence_str})
            batch_sentences.append(sentence)
            batch_offsets.append(offsets)

        pred_list = srl_model.predict_batch_json(batch_json_list)

        for sentence, offsets, pred in zip(batch_sentences, batch_offsets, pred_list):
            print(sentence)
            print(pred)
            if len(pred['verbs']):
                try:
                    if len(sentence) != len(pred['words']):
                        mapping = try_simple_alignment(sentence, pred['words'])
                    else:
                        mapping = {idx: idx for idx in range(len(sentence))}

                    tag_dict_list = parse_output(pred)
                    for tag_dict in tag_dict_list:
                        verb = tag_dict['V']
                        arg0 = tag_dict.get('ARG0', [])
                        arg1 = tag_dict.get('ARG1', [])
                        loc = tag_dict.get('ARGM-LOC', [])
                        tmp = tag_dict.get('ARGM-TMP', [])

                        srl_info = [verb, arg0, arg1, loc, tmp]

                        mapped_srl_info = []
                        for idx_list in srl_info:
                            span_boundary = []
                            if len(idx_list):
                                try:
                                    span_boundary = (
                                        offsets[mapping[idx_list[0]]][0], offsets[mapping[idx_list[-1]]][1])
                                except KeyError:
                                    print("Noooooo")
                                    import sys
                                    sys.exit()

                            mapped_srl_info.append(span_boundary)

                        srl_info_list.append(mapped_srl_info)

                except AssertionError:
                    print(sentence, pred['words'])
                    break

        output_dict = dict(instance)
        output_dict['srl_info'] = srl_info_list
        
        break
# Out:
# ('Teacher', 'convicted', 'of', 'aiding', 'Pakistani', 'terror', 'group', 'McLEAN', ',', 'Va', '.', '.')
# {'verbs': [{'verb': 'convicted', 'description': '[ARG1: Teacher] [V: convicted] [ARG2: of aiding Pakistani terror group McLEAN , Va .] .', 'tags': ['B-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'aiding', 'description': '[ARG0: Teacher] convicted of [V: aiding] [ARG1: Pakistani terror group McLEAN , Va .] .', 'tags': ['B-ARG0', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}], 'words': ['Teacher', 'convicted', 'of', 'aiding', 'Pakistani', 'terror', 'group', 'McLEAN', ',', 'Va', '.', '.']}
# ('A', 'Maryland', 'teacher', 'has', 'been', 'convicted', 'of', 'lending', 'aid', 'to', 'a', 'Pakistani', 'terrorist', 'organization', '.')
# {'verbs': [{'verb': 'has', 'description': 'A Maryland teacher [V: has] been convicted of lending aid to a Pakistani terrorist organization .', 'tags': ['O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'been', 'description': 'A Maryland teacher has [V: been] convicted of lending aid to a Pakistani terrorist organization .', 'tags': ['O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'convicted', 'description': '[ARG1: A Maryland teacher] has been [V: convicted] [ARG2: of lending aid to a Pakistani terrorist organization] .', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'lending', 'description': '[ARG0: A Maryland teacher] has been convicted of [V: lending] [ARG1: aid] [ARG2: to a Pakistani terrorist organization] .', 'tags': ['B-ARG0', 'I-ARG0', 'I-ARG0', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}], 'words': ['A', 'Maryland', 'teacher', 'has', 'been', 'convicted', 'of', 'lending', 'aid', 'to', 'a', 'Pakistani', 'terrorist', 'organization', '.']}
# ('The', 'conviction', 'of', '29', '-', 'year', '-', 'old', 'Ali', 'Asad', 'Chandia', 'is', 'the', 'government', "'", 's', '11th', 'conviction', 'in', 'its', 'investigation', 'of', 'what', 'it', 'called', 'a', '"', 'Virginia', 'jihad', 'network', '"', 'that', 'used', 'paintball', 'games', 'to', 'train', 'for', 'global', 'holy', 'war', '.')
# {'verbs': [{'verb': 'is', 'description': '[ARG1: The conviction of 29 - year - old Ali Asad Chandia] [V: is] [ARG2: the government \' s 11th conviction in its investigation of what it called a " Virginia jihad network " that used paintball games to train for global holy war] .', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'called', 'description': 'The conviction of 29 - year - old Ali Asad Chandia is the government \' s 11th conviction in its investigation of [ARG1: what] [ARG0: it] [V: called] [ARG2: a " Virginia jihad network " that used paintball games to train for global holy war] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'B-ARG0', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'used', 'description': 'The conviction of 29 - year - old Ali Asad Chandia is the government \' s 11th conviction in its investigation of what it called [ARG0: a " Virginia jihad network "] [R-ARG0: that] [V: used] [ARG1: paintball games] [ARG2: to train for global holy war] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'B-R-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'train', 'description': 'The conviction of 29 - year - old Ali Asad Chandia is the government \' s 11th conviction in its investigation of what it called a " Virginia jihad network " [ARG0: that] used paintball games to [V: train] [ARG1: for global holy war] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}], 'words': ['The', 'conviction', 'of', '29', '-', 'year', '-', 'old', 'Ali', 'Asad', 'Chandia', 'is', 'the', 'government', "'", 's', '11th', 'conviction', 'in', 'its', 'investigation', 'of', 'what', 'it', 'called', 'a', '"', 'Virginia', 'jihad', 'network', '"', 'that', 'used', 'paintball', 'games', 'to', 'train', 'for', 'global', 'holy', 'war', '.']}
# ('Chandia', ',', 'a', 'third', '-', 'grade', 'teacher', 'at', 'a', 'Muslim', 'school', 'in', 'College', 'Park', ',', 'was', 'convicted', 'on', 'three', 'of', 'the', 'four', 'counts', 'he', 'faced', ',', 'including', 'providing', 'material', 'support', 'to', 'a', 'foreign', 'terrorist', 'organization', 'and', 'conspiracy', 'to', 'do', 'the', 'same', '.')
# {'verbs': [{'verb': 'was', 'description': 'Chandia , a third - grade teacher at a Muslim school in College Park , [V: was] convicted on three of the four counts he faced , including providing material support to a foreign terrorist organization and conspiracy to do the same .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'convicted', 'description': '[ARG1: Chandia , a third - grade teacher at a Muslim school in College Park ,] was [V: convicted] [ARG2: on three of the four counts he faced , including providing material support to a foreign terrorist organization and conspiracy to do the same] .', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'faced', 'description': 'Chandia , a third - grade teacher at a Muslim school in College Park , was convicted on three of [ARG1: the four counts] [ARG0: he] [V: faced] , including providing material support to a foreign terrorist organization and conspiracy to do the same .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARG0', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'including', 'description': 'Chandia , a third - grade teacher at a Muslim school in College Park , was convicted on three of [ARG2: the four counts] he faced , [V: including] [ARG1: providing material support to a foreign terrorist organization and conspiracy to do the same] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'providing', 'description': 'Chandia , a third - grade teacher at a Muslim school in College Park , was convicted on three of the four counts he faced , including [V: providing] [ARG1: material support] [ARG2: to a foreign terrorist organization] and conspiracy to do the same .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'do', 'description': 'Chandia , a third - grade teacher at a Muslim school in College Park , was convicted on three of the four counts he faced , including providing material support to a foreign terrorist organization and conspiracy to [V: do] [ARG1: the same] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'O']}], 'words': ['Chandia', ',', 'a', 'third', '-', 'grade', 'teacher', 'at', 'a', 'Muslim', 'school', 'in', 'College', 'Park', ',', 'was', 'convicted', 'on', 'three', 'of', 'the', 'four', 'counts', 'he', 'faced', ',', 'including', 'providing', 'material', 'support', 'to', 'a', 'foreign', 'terrorist', 'organization', 'and', 'conspiracy', 'to', 'do', 'the', 'same', '.']}
# ('The', 'government', 'says', 'that', 'Chandia', 'traveled', 'to', 'Pakistan', 'after', 'the', 'September', 'Eleventh', 'attacks', 'and', 'received', 'military', 'training', 'from', 'a', 'group', 'called', 'Lashkar', '-', 'e', '-', 'Taiba', 'That', 'group', 'is', 'fighting', 'for', 'Muslim', 'control', 'over', 'the', 'disputed', 'Kashmir', 'region', 'on', 'the', 'India', '-', 'Pakistan', 'border', '.')
# {'verbs': [{'verb': 'says', 'description': '[ARG0: The government] [V: says] [ARG1: that Chandia traveled to Pakistan after the September Eleventh attacks and received military training from a group called Lashkar - e - Taiba That group is fighting for Muslim control over the disputed Kashmir region on the India - Pakistan border] .', 'tags': ['B-ARG0', 'I-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'traveled', 'description': 'The government says that [ARG0: Chandia] [V: traveled] [ARG1: to Pakistan] [ARGM-TMP: after the September Eleventh attacks] and received military training from a group called Lashkar - e - Taiba That group is fighting for Muslim control over the disputed Kashmir region on the India - Pakistan border .', 'tags': ['O', 'O', 'O', 'O', 'B-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'received', 'description': 'The government says that [ARG0: Chandia] traveled to Pakistan after the September Eleventh attacks and [V: received] [ARG1: military training] [ARG2: from a group called Lashkar - e - Taiba That group is fighting for Muslim control over the disputed Kashmir region on the India - Pakistan border] .', 'tags': ['O', 'O', 'O', 'O', 'B-ARG0', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'called', 'description': 'The government says that Chandia traveled to Pakistan after the September Eleventh attacks and received military training from [ARG1: a group] [V: called] [ARG2: Lashkar - e - Taiba] That group is fighting for Muslim control over the disputed Kashmir region on the India - Pakistan border .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'is', 'description': 'The government says that Chandia traveled to Pakistan after the September Eleventh attacks and received military training from a group called Lashkar - e - Taiba That group [V: is] fighting for Muslim control over the disputed Kashmir region on the India - Pakistan border .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'fighting', 'description': 'The government says that Chandia traveled to Pakistan after the September Eleventh attacks and received military training from a group called Lashkar - e - Taiba [ARG0: That group] is [V: fighting] [ARG2: for Muslim control over the disputed Kashmir region on the India - Pakistan border] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'O', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'disputed', 'description': 'The governme ...
# ('Chandia', 'faces', 'a', 'maximum', 'of', '45', 'years', 'in', 'prison', 'when', 'he', 'is', 'sentenced', 'in', 'August', '.')
# {'verbs': [{'verb': 'faces', 'description': '[ARG0: Chandia] [V: faces] [ARG1: a maximum of 45 years in prison] [ARGM-TMP: when he is sentenced in August] .', 'tags': ['B-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}, {'verb': 'is', 'description': 'Chandia faces a maximum of 45 years in prison when he [V: is] sentenced in August .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O']}, {'verb': 'sentenced', 'description': 'Chandia faces a maximum of 45 years in prison [ARGM-TMP: when] [ARG1: he] is [V: sentenced] [ARGM-TMP: in August] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARGM-TMP', 'B-ARG1', 'O', 'B-V', 'B-ARGM-TMP', 'I-ARGM-TMP', 'O']}], 'words': ['Chandia', 'faces', 'a', 'maximum', 'of', '45', 'years', 'in', 'prison', 'when', 'he', 'is', 'sentenced', 'in', 'August', '.']}
# ('Copyright', '2006', 'Associated', 'Press', '.')
# {'verbs': [], 'words': ['Copyright', '2006', 'Associated', 'Press', '.']}
# ('The', 'teacher', 'of', 'course', 'is', 'himself', 'a', 'Pakistani', 'immigrant', 'to', 'the', 'US', ':', 'Who', 'is', 'Ali', 'Asad', 'Chandia', '?')
# {'verbs': [{'verb': 'is', 'description': '[ARG1: The teacher] [ARGM-DIS: of course] [V: is] [ARGM-REC: himself] [ARG2: a Pakistani immigrant to the US] : Who is Ali Asad Chandia ?', 'tags': ['B-ARG1', 'I-ARG1', 'B-ARGM-DIS', 'I-ARGM-DIS', 'B-V', 'B-ARGM-REC', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'is', 'description': 'The teacher of course is himself a Pakistani immigrant to the US : [ARG2: Who] [V: is] [ARG1: Ali Asad Chandia] ?', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG2', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'O']}], 'words': ['The', 'teacher', 'of', 'course', 'is', 'himself', 'a', 'Pakistani', 'immigrant', 'to', 'the', 'US', ':', 'Who', 'is', 'Ali', 'Asad', 'Chandia', '?']}
# ('Care', '.')
# {'verbs': [{'verb': 'Care', 'description': '[V: Care] .', 'tags': ['B-V', 'O']}], 'words': ['Care', '.']}
# ('The', 'link', 'I', 'posted', 'is', 'Islamicist', '.')
# {'verbs': [{'verb': 'posted', 'description': '[ARG1: The link] [ARG0: I] [V: posted] is Islamicist .', 'tags': ['B-ARG1', 'I-ARG1', 'B-ARG0', 'B-V', 'O', 'O', 'O']}, {'verb': 'is', 'description': '[ARG1: The link I posted] [V: is] [ARG2: Islamicist] .', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'O']}], 'words': ['The', 'link', 'I', 'posted', 'is', 'Islamicist', '.']}
# ('The', 'Laskhar', '-', 'e', '-', 'Taiba', 'is', 'an', 'active', 'terrorist', 'group', 'that', 'operates', 'freely', 'in', 'Pakistan', '.')
# {'verbs': [{'verb': 'is', 'description': '[ARG1: The Laskhar - e - Taiba] [V: is] [ARG2: an active terrorist group that operates freely in Pakistan] .', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'operates', 'description': 'The Laskhar - e - Taiba is [ARG0: an active terrorist group] [R-ARG0: that] [V: operates] [ARGM-MNR: freely] [ARGM-LOC: in Pakistan] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'B-R-ARG0', 'B-V', 'B-ARGM-MNR', 'B-ARGM-LOC', 'I-ARGM-LOC', 'O']}], 'words': ['The', 'Laskhar', '-', 'e', '-', 'Taiba', 'is', 'an', 'active', 'terrorist', 'group', 'that', 'operates', 'freely', 'in', 'Pakistan', '.']}
# ('They', 'represent', 'the', 'scum', 'of', 'the', 'earth', '.')
# {'verbs': [{'verb': 'represent', 'description': '[ARG0: They] [V: represent] [ARG1: the scum of the earth] .', 'tags': ['B-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}], 'words': ['They', 'represent', 'the', 'scum', 'of', 'the', 'earth', '.']}
# ('The', 'teacher', 'of', 'course', 'is', 'himself', 'a', 'Pakistani', 'immigrant', 'to', 'the', 'US', ':', 'Who', 'is', 'Ali', 'Asad', 'Chandia', '?')
# {'verbs': [{'verb': 'is', 'description': '[ARG1: The teacher] [ARGM-DIS: of course] [V: is] [ARGM-REC: himself] [ARG2: a Pakistani immigrant to the US] : Who is Ali Asad Chandia ?', 'tags': ['B-ARG1', 'I-ARG1', 'B-ARGM-DIS', 'I-ARGM-DIS', 'B-V', 'B-ARGM-REC', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'is', 'description': 'The teacher of course is himself a Pakistani immigrant to the US : [ARG2: Who] [V: is] [ARG1: Ali Asad Chandia] ?', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG2', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'O']}], 'words': ['The', 'teacher', 'of', 'course', 'is', 'himself', 'a', 'Pakistani', 'immigrant', 'to', 'the', 'US', ':', 'Who', 'is', 'Ali', 'Asad', 'Chandia', '?']}
# ('Care', '.')
# {'verbs': [{'verb': 'Care', 'description': '[V: Care] .', 'tags': ['B-V', 'O']}], 'words': ['Care', '.']}
# ('The', 'link', 'I', 'posted', 'is', 'Islamicist', '.')
# {'verbs': [{'verb': 'posted', 'description': '[ARG1: The link] [ARG0: I] [V: posted] is Islamicist .', 'tags': ['B-ARG1', 'I-ARG1', 'B-ARG0', 'B-V', 'O', 'O', 'O']}, {'verb': 'is', 'description': '[ARG1: The link I posted] [V: is] [ARG2: Islamicist] .', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'O']}], 'words': ['The', 'link', 'I', 'posted', 'is', 'Islamicist', '.']}
# ('Love', 'how', 'they', 'insist', 'that', 'he', "'", 's', 'done', 'nothing', 'wrong', '.', '.', '.', '.')
# {'verbs': [{'verb': 'Love', 'description': "[V: Love] [ARG1: how they insist that he ' s done nothing wrong] . . . .", 'tags': ['B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O']}, {'verb': 'insist', 'description': "Love [ARGM-MNR: how] [ARG0: they] [V: insist] [ARG1: that he ' s done nothing wrong] . . . .", 'tags': ['O', 'B-ARGM-MNR', 'B-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O']}, {'verb': 'done', 'description': "Love how they insist that [ARG0: he] ' s [V: done] [ARG1: nothing wrong] . . . .", 'tags': ['O', 'O', 'O', 'O', 'O', 'B-ARG0', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O']}], 'words': ['Love', 'how', 'they', 'insist', 'that', 'he', "'", 's', 'done', 'nothing', 'wrong', '.', '.', '.', '.']}
# ('One', 'also', 'wonders', 'if', 'poverty', 'has', 'anything', 'to', 'do', 'with', 'terrorism', ',', 'as', 'claimed', 'by', 'many', 'peaceniks', '.')
# {'verbs': [{'verb': 'wonders', 'description': '[ARG0: One] [ARGM-ADV: also] [V: wonders] [ARG1: if poverty has anything to do with terrorism , as claimed by many peaceniks] .', 'tags': ['B-ARG0', 'B-ARGM-ADV', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'has', 'description': 'One also wonders if [ARG0: poverty] [V: has] [ARG1: anything to do with terrorism] , [ARGM-ADV: as claimed by many peaceniks] .', 'tags': ['O', 'O', 'O', 'O', 'B-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'B-ARGM-ADV', 'I-ARGM-ADV', 'I-ARGM-ADV', 'I-ARGM-ADV', 'I-ARGM-ADV', 'O']}, {'verb': 'do', 'description': 'One also wonders if poverty has [ARG2: anything] to [V: do] [ARG1: with terrorism] , as claimed by many peaceniks .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ARG2', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'claimed', 'description': 'One also wonders if poverty has anything to do with terrorism , as [V: claimed] [ARG0: by many peaceniks] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'O']}], 'words': ['One', 'also', 'wonders', 'if', 'poverty', 'has', 'anything', 'to', 'do', 'with', 'terrorism', ',', 'as', 'claimed', 'by', 'many', 'peaceniks', '.']}
# ('Its', 'Ideology', ',', 'thats', 'always', 'been', 'the', 'motivator', 'for', 'terrorists', ',', 'this', 'is', 'something', 'the', 'peaceniks', 'fail', 'to', 'understand', 'time', 'and', 'again', '.')
# {'verbs': [{'verb': 's', 'description': 'Its Ideology , that [V: s] always been the motivator for terrorists , this is something the peaceniks fail to understand time and again .', 'tags': ['O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'been', 'description': '[ARG1: Its Ideology] , [R-ARG1: that] s [ARGM-TMP: always] [V: been] [ARG2: the motivator for terrorists] , this is something the peaceniks fail to understand time and again .', 'tags': ['B-ARG1', 'I-ARG1', 'O', 'B-R-ARG1', 'O', 'B-ARGM-TMP', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'is', 'description': 'Its Ideology , that s always been the motivator for terrorists , [ARG1: this] [V: is] [ARG2: something the peaceniks fail to understand time and again] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'fail', 'description': 'Its Ideology , that s always been the motivator for terrorists , this is something [ARG1: the peaceniks] [V: fail] [ARG2: to understand] [ARGM-TMP: time and again] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}, {'verb': 'understand', 'description': 'Its Ideology , that s always been the motivator for terrorists , this is [ARG1: something] [ARG0: the peaceniks] fail to [V: understand] [ARGM-TMP: time and again] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'B-ARG0', 'I-ARG0', 'O', 'O', 'B-V', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}], 'words': ['Its', 'Ideology', ',', 'that', 's', 'always', 'been', 'the', 'motivator', 'for', 'terrorists', ',', 'this', 'is', 'something', 'the', 'peaceniks', 'fail', 'to', 'understand', 'time', 'and', 'again', '.']}
# ('This', 'particular', 'Pakistani', 'origin', 'terrorist', 'will', 'not', 'be', 'troubling', 'the', 'world', 'for', 'some', 'time', ':')
# {'verbs': [{'verb': 'will', 'description': 'This particular Pakistani origin terrorist [V: will] not be troubling the world for some time :', 'tags': ['O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'be', 'description': '[ARG1: This particular Pakistani origin terrorist] [ARGM-MOD: will] [ARGM-NEG: not] [V: be] [ARG2: troubling the world] [ARGM-TMP: for some time] :', 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARGM-MOD', 'B-ARGM-NEG', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}, {'verb': 'troubling', 'description': '[ARG0: This particular Pakistani origin terrorist] [ARGM-MOD: will] [ARGM-NEG: not] be [V: troubling] [ARG1: the world] [ARGM-TMP: for some time] :', 'tags': ['B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'B-ARGM-MOD', 'B-ARGM-NEG', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}], 'words': ['This', 'particular', 'Pakistani', 'origin', 'terrorist', 'will', 'not', 'be', 'troubling', 'the', 'world', 'for', 'some', 'time', ':']}
# ('Saturday', ',', 'August', '26', ',', '2006', '11', ':', '36', ':', '00', 'Am', 'Pak', 'teacher', 'in', 'US', 'jailed', 'for', 'aiding', 'terrorists', 'Arun', 'Kumar', 'Washington', ':', 'A', 'third', '-', 'grade', 'Pakistani', 'teacher', 'at', 'a', 'Muslim', 'school', ',', 'the', 'last', 'of', '11', 'members', 'of', 'the', '"', 'Virginia', 'jihad', 'network', '"', 'charged', 'with', 'aiding', 'an', 'anti', '-', 'India', 'terrorist', 'group', ',', 'was', 'sentenced', 'to', '15', 'years', 'in', 'prison', '.')
# {'verbs': [{'verb': 'Am', 'description': '[ARGM-TMP: Saturday ,] [ARGM-TMP: August 26 , 2006 11 : 36 :] 00 [V: Am] [ARG2: Pak teacher in US jailed for aiding terrorists Arun Kumar Washington : A third - grade Pakistani teacher at a Muslim school] , the last of 11 members of the " Virginia jihad network " charged with aiding an anti - India terrorist group , was sentenced to 15 years in prison .', 'tags': ['B-ARGM-TMP', 'I-ARGM-TMP', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'jailed', 'description': 'Saturday , August 26 , 2006 11 : 36 : 00 Am Pak teacher in US [V: jailed] [ARG3: for aiding terrorists Arun Kumar Washington] : A third - grade Pakistani teacher at a Muslim school , the last of 11 members of the " Virginia jihad network " charged with aiding an anti - India terrorist group , was sentenced to 15 years in prison .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG3', 'I-ARG3', 'I-ARG3', 'I-ARG3', 'I-ARG3', 'I-ARG3', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'aiding', 'description': 'Saturday , August 26 , 2006 11 : 36 : 00 Am Pak teacher in US jailed for [V: aiding] [ARG1: terrorists Arun Kumar Washington] : A third - grade Pakistani teacher at a Muslim school , the last of 11 members of the " Virginia jihad network " charged with aiding an anti - India terrorist group , was sentenced to 15 years in prison .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'charged', 'description': 'Saturday , August 26 , 2006 11 : 36 : 00 Am Pak teacher in US jailed for aiding terrorists Arun Kumar Washington : A third - grade Pakistani teacher at a Muslim school , the last of 11 members of [ARG1: the " Virginia jihad network "] [V: charged] [ARG2: with aiding an anti - India terrorist group] , was sentenced to 15 years in prison .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'aiding', 'description': 'Saturday , August 26 , 2006 11 : 36 : 00 Am Pak teacher in US jailed for aiding terrorists Arun Kumar Washington : A third - grade Pakistani teacher at a Muslim school , the last of 11 members of the " Virginia jihad network " charged with [V: aiding] [ARG1: an anti - India terrorist group] , was sentenced to 15 years in prison .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'was', 'description': 'Saturday , August 26 , 2006 11 : 36 : 00 Am ...
# ('Prosecutors', 'had', 'sought', 'a', 'sentence', 'of', '30', 'years', 'to', 'life', 'in', 'prison', 'for', 'Ali', 'Asad', 'Chandia', ',', '29', ',', 'one', 'of', 'the', '11', 'Muslim', 'men', 'charged', 'in', 'US', 'District', 'Court', 'in', 'Alexandria', 'in', 'June', '2003', 'with', 'training', 'with', 'and', 'fighting', 'for', 'Lashkar', '-', 'e', '-', 'Taiba', '.')
# {'verbs': [{'verb': 'had', 'description': 'Prosecutors [V: had] sought a sentence of 30 years to life in prison for Ali Asad Chandia , 29 , one of the 11 Muslim men charged in US District Court in Alexandria in June 2003 with training with and fighting for Lashkar - e - Taiba .', 'tags': ['O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'sought', 'description': '[ARG0: Prosecutors] had [V: sought] [ARG1: a sentence of 30 years to life in prison] [ARGM-CAU: for Ali Asad Chandia , 29 , one of the 11 Muslim men charged in US District Court in Alexandria in June 2003 with training with and fighting for Lashkar - e - Taiba] .', 'tags': ['B-ARG0', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'O']}, {'verb': 'charged', 'description': 'Prosecutors had sought a sentence of 30 years to life in prison for Ali Asad Chandia , 29 , one of [ARG1: the 11 Muslim men] [V: charged] [ARGM-LOC: in US District Court in Alexandria] [ARGM-TMP: in June 2003] [ARG2: with training with and fighting for Lashkar - e - Taiba] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}, {'verb': 'fighting', 'description': 'Prosecutors had sought a sentence of 30 years to life in prison for Ali Asad Chandia , 29 , one of the 11 Muslim men charged in US District Court in Alexandria in June 2003 with training with and [V: fighting] [ARG2: for Lashkar - e - Taiba] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O']}], 'words': ['Prosecutors', 'had', 'sought', 'a', 'sentence', 'of', '30', 'years', 'to', 'life', 'in', 'prison', 'for', 'Ali', 'Asad', 'Chandia', ',', '29', ',', 'one', 'of', 'the', '11', 'Muslim', 'men', 'charged', 'in', 'US', 'District', 'Court', 'in', 'Alexandria', 'in', 'June', '2003', 'with', 'training', 'with', 'and', 'fighting', 'for', 'Lashkar', '-', 'e', '-', 'Taiba', '.']}
# ('Chandia', ',', 'they', 'said', ',', 'trained', 'at', 'a', 'Lashkar', 'camp', 'in', 'Pakistan', 'and', 'helped', 'the', 'group', 'acquire', 'paintballs', 'and', 'other', 'equipment', 'with', 'potential', 'military', 'applications', 'when', 'he', 'returned', 'to', 'the', 'United', 'States', '.')
# {'verbs': [{'verb': 'said', 'description': '[ARG1: Chandia] , [ARG0: they] [V: said] , [C-ARG1: trained at a Lashkar camp in Pakistan and helped the group acquire paintballs and other equipment with potential military applications when he returned to the United States] .', 'tags': ['B-ARG1', 'O', 'B-ARG0', 'B-V', 'O', 'B-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'I-C-ARG1', 'O']}, {'verb': 'trained', 'description': '[ARG2: Chandia] , they said , [V: trained] [ARGM-LOC: at a Lashkar camp in Pakistan] and helped the group acquire paintballs and other equipment with potential military applications when he returned to the United States .', 'tags': ['B-ARG2', 'O', 'O', 'O', 'O', 'B-V', 'B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'helped', 'description': '[ARG0: Chandia] , they said , trained at a Lashkar camp in Pakistan and [V: helped] [ARG1: the group acquire paintballs and other equipment with potential military applications] [ARGM-TMP: when he returned to the United States] .', 'tags': ['B-ARG0', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}, {'verb': 'returned', 'description': 'Chandia , they said , trained at a Lashkar camp in Pakistan and helped the group acquire paintballs and other equipment with potential military applications [ARGM-TMP: when] [ARG1: he] [V: returned] [ARG4: to the United States] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARGM-TMP', 'B-ARG1', 'B-V', 'B-ARG4', 'I-ARG4', 'I-ARG4', 'I-ARG4', 'O']}], 'words': ['Chandia', ',', 'they', 'said', ',', 'trained', 'at', 'a', 'Lashkar', 'camp', 'in', 'Pakistan', 'and', 'helped', 'the', 'group', 'acquire', 'paintballs', 'and', 'other', 'equipment', 'with', 'potential', 'military', 'applications', 'when', 'he', 'returned', 'to', 'the', 'United', 'States', '.']}
# ('The', 'equipment', 'included', 'unmanned', 'aerial', 'vehicles', ',', 'night', '-', 'vision', 'equipment', 'and', 'wireless', 'video', 'cameras', '.')
# {'verbs': [{'verb': 'included', 'description': '[ARG2: The equipment] [V: included] [ARG1: unmanned aerial vehicles , night - vision equipment and wireless video cameras] .', 'tags': ['B-ARG2', 'I-ARG2', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}], 'words': ['The', 'equipment', 'included', 'unmanned', 'aerial', 'vehicles', ',', 'night', '-', 'vision', 'equipment', 'and', 'wireless', 'video', 'cameras', '.']}
# ('Federal', 'investigators', 'also', 'found', 'a', 'CD', '-', 'ROM', 'in', 'Chandia', "'", 's', 'car', 'containing', 'videos', 'that', 'glorified', 'Osama', 'bin', 'Laden', 'and', 'the', '19', 'hijackers', 'who', 'carried', 'out', 'the', 'Sep', '11', 'attacks', ',', 'prosecutors', 'said', '.')
# {'verbs': [{'verb': 'found', 'description': "[ARG0: Federal investigators] [ARGM-ADV: also] [V: found] [ARG1: a CD - ROM] [ARGM-LOC: in Chandia ' s car] [ARG1: containing videos that glorified Osama bin Laden and the 19 hijackers who carried out the Sep 11 attacks] , prosecutors said .", 'tags': ['B-ARG0', 'I-ARG0', 'B-ARGM-ADV', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O']}, {'verb': 'containing', 'description': "Federal investigators also found [ARG0: a CD - ROM] in Chandia ' s car [V: containing] [ARG1: videos that glorified Osama bin Laden and the 19 hijackers who carried out the Sep 11 attacks] , prosecutors said .", 'tags': ['O', 'O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O']}, {'verb': 'glorified', 'description': "Federal investigators also found a CD - ROM in Chandia ' s car containing [ARG0: videos] [R-ARG0: that] [V: glorified] [ARG1: Osama bin Laden and the 19 hijackers who carried out the Sep 11 attacks] , prosecutors said .", 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'B-R-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O']}, {'verb': 'carried', 'description': "Federal investigators also found a CD - ROM in Chandia ' s car containing videos that glorified Osama bin Laden and [ARG0: the 19 hijackers] [R-ARG0: who] [V: carried] out [ARG1: the Sep 11 attacks] , prosecutors said .", 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'B-R-ARG0', 'B-V', 'O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O']}, {'verb': 'said', 'description': "[ARG1: Federal investigators also found a CD - ROM in Chandia ' s car containing videos that glorified Osama bin Laden and the 19 hijackers who carried out the Sep 11 attacks] , [ARG0: prosecutors] [V: said] .", 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'B-ARG0', 'B-V', 'O']}], 'words': ['Federal', 'investigators', 'also', 'found', 'a', 'CD', '-', 'ROM', 'in', 'Chandia', "'", 's', 'car', 'containing', 'videos', 'that', 'glorified', 'Osama', 'bin', 'Laden', 'and', 'the', '19', 'hijackers', 'who', 'carried', 'out', 'the', 'Sep', '11', 'attacks', ',', 'prosecutors', 'said', '.']}
# ('District', 'Judge', 'Claude', 'M', '.', 'Hilton', 'in', 'Alexandria', 'did', 'not', 'explain', 'his', 'reasoning', 'as', 'he', 'imposed', 'the', 'sentence', 'and', 'ordered', 'Chandia', ',', 'who', 'had', 'been', 'free', 'on', 'bond', ',', 'into', 'custody', '.')
# {'verbs': [{'verb': 'did', 'description': 'District Judge Claude M . Hilton in Alexandria [V: did] not explain his reasoning as he imposed the sentence and ordered Chandia , who had been free on bond , into custody .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'explain', 'description': '[ARG0: District Judge Claude M . Hilton in Alexandria] did [ARGM-NEG: not] [V: explain] [ARG1: his reasoning] [ARGM-TMP: as he imposed the sentence and ordered Chandia , who had been free on bond , into custody] .', 'tags': ['B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'O', 'B-ARGM-NEG', 'B-V', 'B-ARG1', 'I-ARG1', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}, {'verb': 'imposed', 'description': 'District Judge Claude M . Hilton in Alexandria did not explain his reasoning as [ARG0: he] [V: imposed] [ARG1: the sentence] and ordered Chandia , who had been free on bond , into custody .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'ordered', 'description': 'District Judge Claude M . Hilton in Alexandria did not explain his reasoning as [ARG0: he] imposed the sentence and [V: ordered] [ARG1: Chandia , who had been free on bond] , [ARG2: into custody] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'B-ARG2', 'I-ARG2', 'O']}, {'verb': 'had', 'description': 'District Judge Claude M . Hilton in Alexandria did not explain his reasoning as he imposed the sentence and ordered Chandia , who [V: had] been free on bond , into custody .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'been', 'description': 'District Judge Claude M . Hilton in Alexandria did not explain his reasoning as he imposed the sentence and ordered [ARG1: Chandia] , [R-ARG1: who] had [V: been] [ARG2: free] [ARGM-MNR: on bond] , into custody .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG1', 'O', 'B-R-ARG1', 'O', 'B-V', 'B-ARG2', 'B-ARGM-MNR', 'I-ARGM-MNR', 'O', 'O', 'O', 'O']}], 'words': ['District', 'Judge', 'Claude', 'M', '.', 'Hilton', 'in', 'Alexandria', 'did', 'not', 'explain', 'his', 'reasoning', 'as', 'he', 'imposed', 'the', 'sentence', 'and', 'ordered', 'Chandia', ',', 'who', 'had', 'been', 'free', 'on', 'bond', ',', 'into', 'custody', '.']}
# ('Earlier', ',', 'Chandia', ',', 'who', 'teaches', 'at', 'a', 'Muslim', 'school', 'in', 'Maryland', ',', 'had', 'told', 'the', 'judge', 'that', 'he', 'did', 'not', '"', 'deserve', 'to', 'spend', 'a', 'single', 'day', 'in', 'prison', '.', '"')
# {'verbs': [{'verb': 'teaches', 'description': 'Earlier , [ARG0: Chandia] , [R-ARG0: who] [V: teaches] [ARGM-LOC: at a Muslim school in Maryland] , had told the judge that he did not " deserve to spend a single day in prison . "', 'tags': ['O', 'O', 'B-ARG0', 'O', 'B-R-ARG0', 'B-V', 'B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'had', 'description': 'Earlier , Chandia , who teaches at a Muslim school in Maryland , [V: had] told the judge that he did not " deserve to spend a single day in prison . "', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'told', 'description': '[ARGM-TMP: Earlier] , [ARG0: Chandia , who teaches at a Muslim school in Maryland] , had [V: told] [ARG2: the judge] [ARG1: that he did not " deserve to spend a single day in prison] . "', 'tags': ['B-ARGM-TMP', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'O', 'O', 'B-V', 'B-ARG2', 'I-ARG2', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O']}, {'verb': 'did', 'description': 'Earlier , Chandia , who teaches at a Muslim school in Maryland , had told the judge that he [V: did] not " deserve to spend a single day in prison . "', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'deserve', 'description': 'Earlier , Chandia , who teaches at a Muslim school in Maryland , had told the judge that [ARG0: he] did [ARGM-NEG: not] " [V: deserve] [ARG1: to spend a single day in prison] . "', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'O', 'B-ARGM-NEG', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O']}, {'verb': 'spend', 'description': 'Earlier , Chandia , who teaches at a Muslim school in Maryland , had told the judge that [ARG0: he] did not " deserve to [V: spend] [ARG1: a single day] [ARGM-LOC: in prison] . "', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARGM-LOC', 'I-ARGM-LOC', 'O', 'O']}], 'words': ['Earlier', ',', 'Chandia', ',', 'who', 'teaches', 'at', 'a', 'Muslim', 'school', 'in', 'Maryland', ',', 'had', 'told', 'the', 'judge', 'that', 'he', 'did', 'not', '"', 'deserve', 'to', 'spend', 'a', 'single', 'day', 'in', 'prison', '.', '"']}
# ('With', 'his', 'voice', 'shaking', 'and', 'rising', 'in', 'anger', ',', 'Chandia', 'said', ':', '"', 'With', 'Allah', 'as', 'my', 'witness', ',', 'I', 'tell', 'everyone', 'that', 'I', 'am', 'innocent', '.', '.', '.', 'God', 'knows', 'that', 'I', 'did', 'not', 'support', 'and', 'would', 'not', 'support', 'any', 'terrorists', '.', '"')
# ...
# ('In', 'a', 'search', 'of', 'Chandia', "'", 's', 'home', 'conducted', 'on', 'May', '8', ',', '2003', ',', 'the', 'FBI', 'found', 'audiotapes', 'and', 'other', 'materials', 'manifesting', 'his', 'commitment', 'to', 'violent', 'jihad', '.')
# {'verbs': [{'verb': 'conducted', 'description': "In [ARG1: a search of Chandia ' s home] [V: conducted] [ARGM-TMP: on May 8 , 2003] , the FBI found audiotapes and other materials manifesting his commitment to violent jihad .", 'tags': ['O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'found', 'description': "[ARGM-LOC: In a search of Chandia ' s home conducted on May 8 , 2003] , [ARG0: the FBI] [V: found] [ARG1: audiotapes and other materials manifesting his commitment to violent jihad] .", 'tags': ['B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'O', 'B-ARG0', 'I-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'manifesting', 'description': "In a search of Chandia ' s home conducted on May 8 , 2003 , the FBI found [ARG2: audiotapes and other materials] [V: manifesting] [ARG1: his commitment to violent jihad] .", 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}], 'words': ['In', 'a', 'search', 'of', 'Chandia', "'", 's', 'home', 'conducted', 'on', 'May', '8', ',', '2003', ',', 'the', 'FBI', 'found', 'audiotapes', 'and', 'other', 'materials', 'manifesting', 'his', 'commitment', 'to', 'violent', 'jihad', '.']}
# ('On', 'the', 'front', 'seat', 'of', 'Chandia', "'", 's', 'car', ',', 'the', 'FBI', 'also', 'found', 'a', 'CD', '-', 'ROM', 'containing', 'videos', 'glorifying', 'the', 'Sep', '11', ',', '2001', ',', 'terrorist', 'attacks', ',', 'Osama', 'bin', 'Laden', 'and', 'the', '19', 'hijackers', 'who', 'carried', 'out', 'the', 'attacks', '.')
# {'verbs': [{'verb': 'found', 'description': "[ARGM-LOC: On the front seat of Chandia ' s car] , [ARG0: the FBI] [ARGM-DIS: also] [V: found] [ARG1: a CD - ROM containing videos glorifying the Sep 11 , 2001 , terrorist attacks , Osama bin Laden and the 19 hijackers who carried out the attacks] .", 'tags': ['B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'O', 'B-ARG0', 'I-ARG0', 'B-ARGM-DIS', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'containing', 'description': "On the front seat of Chandia ' s car , the FBI also found [ARG0: a CD - ROM] [V: containing] [ARG1: videos glorifying the Sep 11 , 2001 , terrorist attacks , Osama bin Laden and the 19 hijackers who carried out the attacks] .", 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'glorifying', 'description': "On the front seat of Chandia ' s car , the FBI also found a CD - ROM containing [ARG0: videos] [V: glorifying] [ARG1: the Sep 11 , 2001 , terrorist attacks , Osama bin Laden and the 19 hijackers who carried out the attacks] .", 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'carried', 'description': "On the front seat of Chandia ' s car , the FBI also found a CD - ROM containing videos glorifying the Sep 11 , 2001 , terrorist attacks , Osama bin Laden and [ARG0: the 19 hijackers] [R-ARG0: who] [V: carried] out [ARG1: the attacks] .", 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'B-R-ARG0', 'B-V', 'O', 'B-ARG1', 'I-ARG1', 'O']}], 'words': ['On', 'the', 'front', 'seat', 'of', 'Chandia', "'", 's', 'car', ',', 'the', 'FBI', 'also', 'found', 'a', 'CD', '-', 'ROM', 'containing', 'videos', 'glorifying', 'the', 'Sep', '11', ',', '2001', ',', 'terrorist', 'attacks', ',', 'Osama', 'bin', 'Laden', 'and', 'the', '19', 'hijackers', 'who', 'carried', 'out', 'the', 'attacks', '.']}
# ('They', 'also', 'found', 'a', 'CD', '-', 'ROM', 'containing', 'still', 'photographs', 'of', 'persons', 'jumping', 'to', 'their', 'deaths', 'from', 'the', 'World', 'Trade', 'Center', 'towers', '.')
# {'verbs': [{'verb': 'found', 'description': '[ARG0: They] [ARGM-DIS: also] [V: found] [ARG1: a CD - ROM containing still photographs of persons jumping to their deaths from the World Trade Center towers] .', 'tags': ['B-ARG0', 'B-ARGM-DIS', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'containing', 'description': 'They also found [ARG0: a CD - ROM] [V: containing] [ARG1: still photographs of persons jumping to their deaths from the World Trade Center towers] .', 'tags': ['O', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O']}, {'verb': 'jumping', 'description': 'They also found a CD - ROM containing still photographs of [ARG0: persons] [V: jumping] [ARGM-DIR: to their deaths] [ARGM-DIR: from the World Trade Center towers] .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'B-V', 'B-ARGM-DIR', 'I-ARGM-DIR', 'I-ARGM-DIR', 'B-ARGM-DIR', 'I-ARGM-DIR', 'I-ARGM-DIR', 'I-ARGM-DIR', 'I-ARGM-DIR', 'I-ARGM-DIR', 'O']}], 'words': ['They', 'also', 'found', 'a', 'CD', '-', 'ROM', 'containing', 'still', 'photographs', 'of', 'persons', 'jumping', 'to', 'their', 'deaths', 'from', 'the', 'World', 'Trade', 'Center', 'towers', '.']}
# ('"', 'Terrorist', 'organisations', 'like', 'Lashkar', '-', 'e', '-', 'Taiba', 'rely', 'on', 'a', 'network', 'of', 'individuals', 'to', 'carry', 'out', 'their', 'deadly', 'operations', ',', '"', 'US', 'Attorney', 'Rosenberg', 'said', 'after', 'the', 'sentencing', '.')
# {'verbs': [{'verb': 'rely', 'description': '" [ARG0: Terrorist organisations like Lashkar - e - Taiba] [V: rely] [ARG1: on a network of individuals] [ARG2: to carry out their deadly operations] , " US Attorney Rosenberg said after the sentencing .', 'tags': ['O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'I-ARG0', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'carry', 'description': '" Terrorist organisations like Lashkar - e - Taiba rely on [ARG0: a] network of individuals to [V: carry] out [ARG1: their deadly operations] , " US Attorney Rosenberg said after the sentencing .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'O', 'O', 'O', 'O', 'B-V', 'O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'said', 'description': '" [ARG1: Terrorist organisations like Lashkar - e - Taiba rely on a network of individuals to carry out their deadly operations] , " [ARG0: US Attorney Rosenberg] [V: said] [ARGM-TMP: after the sentencing] .', 'tags': ['O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'B-ARG0', 'I-ARG0', 'I-ARG0', 'B-V', 'B-ARGM-TMP', 'I-ARGM-TMP', 'I-ARGM-TMP', 'O']}], 'words': ['"', 'Terrorist', 'organisations', 'like', 'Lashkar', '-', 'e', '-', 'Taiba', 'rely', 'on', 'a', 'network', 'of', 'individuals', 'to', 'carry', 'out', 'their', 'deadly', 'operations', ',', '"', 'US', 'Attorney', 'Rosenberg', 'said', 'after', 'the', 'sentencing', '.']}
# ('"', 'Ali', 'Asad', 'Chandia', 'was', 'a', 'member', 'of', 'that', 'network', 'for', 'Lashkar', '-', 'e', '-', 'Taiba', ',', 'and', 'he', 'will', 'now', 'spend', 'a', 'very', 'long', 'period', 'of', 'time', 'in', 'prison', 'for', 'providing', 'material', 'support', 'in', 'furtherance', 'of', 'its', 'violent', 'agenda', ',', '"', 'he', 'added', '.')
# {'verbs': [{'verb': 'was', 'description': '" [ARG1: Ali Asad Chandia] [V: was] [ARG2: a member of that network for Lashkar - e - Taiba] , and he will now spend a very long period of time in prison for providing material support in furtherance of its violent agenda , " he added .', 'tags': ['O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'I-ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'will', 'description': '" Ali Asad Chandia was a member of that network for Lashkar - e - Taiba , and he [V: will] now spend a very long period of time in prison for providing material support in furtherance of its violent agenda , " he added .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'spend', 'description': '" Ali Asad Chandia was a member of that network for Lashkar - e - Taiba , and [ARG0: he] [ARGM-MOD: will] [ARGM-TMP: now] [V: spend] [ARG1: a very long period of time] [ARGM-LOC: in prison] [ARGM-CAU: for providing material support in furtherance of its violent agenda] , " he added .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'B-ARGM-MOD', 'B-ARGM-TMP', 'B-V', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'B-ARGM-LOC', 'I-ARGM-LOC', 'B-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'I-ARGM-CAU', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'providing', 'description': '" Ali Asad Chandia was a member of that network for Lashkar - e - Taiba , and [ARG0: he] will now spend a very long period of time in prison for [V: providing] [ARG1: material support] [ARGM-ADV: in furtherance of its violent agenda] , " he added .', 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ARG0', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'B-ARG1', 'I-ARG1', 'B-ARGM-ADV', 'I-ARGM-ADV', 'I-ARGM-ADV', 'I-ARGM-ADV', 'I-ARGM-ADV', 'I-ARGM-ADV', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'added', 'description': '" [ARG1: Ali Asad Chandia was a member of that network for Lashkar - e - Taiba , and he will now spend a very long period of time in prison for providing material support in furtherance of its violent agenda] , " [ARG0: he] [V: added] .', 'tags': ['O', 'B-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'I-ARG1', 'O', 'O', 'B-ARG0', 'B-V', 'O']}], 'words': ['"', 'Ali', 'Asad', 'Chandia', 'was', 'a', 'member', 'of', 'that', 'network', 'for', 'Lashkar', '-', 'e', '-', 'Taiba', ',', 'and', 'he', 'will', 'now', 'spend', 'a', 'very', 'long', 'period', 'of', 'time', 'in', 'prison', 'for', 'providing', 'material', 'support', 'in', 'furtherance', 'of', 'its', 'violent', 'agenda', ',', '"', 'he', 'added', '.']}
# ('Good', 'we', 'do', 'nt', 'need', 'or', 'want', 'them', 'in', 'the', 'U', '.', 'S', '.', '.')
# {'verbs': [{'verb': 'do', 'description': 'Good we [V: do] nt need or want them in the U . S . .', 'tags': ['O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'need', 'description': '[ARGM-DIS: Good] [ARG0: we] do [ARGM-NEG: nt] [V: need] or want [ARG1: them] [ARGM-LOC: in the U . S .] .', 'tags': ['B-ARGM-DIS', 'B-ARG0', 'O', 'B-ARGM-NEG', 'B-V', 'O', 'O', 'B-ARG1', 'B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'O']}, {'verb': 'want', 'description': '[ARGM-DIS: Good] [ARG0: we] do [ARGM-NEG: nt] need or [V: want] [ARG1: them] [ARGM-LOC: in the U . S .] .', 'tags': ['B-ARGM-DIS', 'B-ARG0', 'O', 'B-ARGM-NEG', 'O', 'O', 'B-V', 'B-ARG1', 'B-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'I-ARGM-LOC', 'O']}], 'words': ['Good', 'we', 'do', 'nt', 'need', 'or', 'want', 'them', 'in', 'the', 'U', '.', 'S', '.', '.']}
# ('Pakistani', "'", 's', 'are', 'ok', 'with', 'us', 'but', 'not', 'their', 'terrorist', 'bretherin', 'or', 'any', 'other', 'terrorist', 'for', 'that', 'matter', '.')
# {'verbs': [{'verb': 'are', 'description': "[ARG1: Pakistani ' s] [V: are] [ARG2: ok] [ARGM-GOL: with us] but not their terrorist bretherin or any other terrorist for that matter .", 'tags': ['B-ARG1', 'I-ARG1', 'I-ARG1', 'B-V', 'B-ARG2', 'B-ARGM-GOL', 'I-ARGM-GOL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Pakistani', "'", 's', 'are', 'ok', 'with', 'us', 'but', 'not', 'their', 'terrorist', 'bretherin', 'or', 'any', 'other', 'terrorist', 'for', 'that', 'matter', '.']}
