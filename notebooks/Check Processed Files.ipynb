# %%
import json
from os import path

# %%
train_file_path = "/home/shtoshni/Research/events/proc_data/red/three_way/independent/train.128.jsonlines"
train_data = []
with open(train_file_path) as f:
    for line in f:
        train_data.append(json.loads(line.strip()))

# %%
sample_data = train_data[0]
sample_data.keys()
# Out:
# dict_keys(['doc_key', 'sentences', 'clusters', 'sentence_map', 'subtoken_map'])

# %%
print (sample_data['doc_key'])
# Out:
# deft/5c0dd992beaff240f732e0fdacbd49e4.mpdf

# %%
sample_doc = []
for sentence in sample_data['sentences']:
    sample_doc.extend(sentence)

# %%
for cluster in sample_data['clusters']:
    for span_start, span_end, _, _  in cluster:
        print(sample_doc[span_start: span_end + 1])
        
    print()
# Out:
# ['J', '##J', '##M']
# ['J', '##J', '##M']
# ['J', '##J', '##M']
# ['I']
# ['J', '##J', '##M']
# ['you']
# ['J', '##J', '##M']
# ['My']
# ['I']
# ['J', '##J', '##M']
# ['you']
# ['J', '##J', '##M']
# ['I']
# ['I']
# ['I']
# ['I']
# ['me']
# ['I']
# ['I']
# ['I']
# ['you']
#
# ['cop', '##tic', '##ort', '##ho', '##dox', '##y']
# ['cop', '##tic', '##ort', '##ho', '##dox', '##y']
#
# ['Bishops']
# ['Patriarch', '##s']
#
# ['world']
# ['world']
# ['world']
# ['world']
#
# ['faith']
# ['faith']
# ['faith']
# ['faith']
# ['faith']
# ['faith']
# ['faith']
# ['faith']
# ['faith']
# ['faith']
#
# ['Nice', '##a']
# ['Nice', '##a']
#
# ['di', '##vin', '##ity']
# ['di', '##vin', '##ity']
#
# ['Constantinople']
# ['Constantinople']
#
# ['E', '##phe', '##sus']
# ['E', '##phe', '##sus']
# ['E', '##phe', '##sus']
# ['E', '##phe', '##sus']
#
# ['fathers']
# ['Fathers']
#
# ['At', '##hana', '##sius']
# ['At', '##hana', '##sius']
#
# ['accepted']
# ['that']
#
# ['Catholic', 'Church']
# ...
