# %%
import json
from os import path

# %%
train_file_path = "/home/shtoshni/Research/events/proc_data/red/ment_det/independent/dev.128.jsonlines"
train_data = []
with open(train_file_path) as f:
    for line in f:
        train_data.append(json.loads(line.strip()))

# %%
sample_data = train_data[2]
sample_data.keys()
# Out:
# dict_keys(['doc_key', 'sentences', 'mentions', 'sentence_map', 'subtoken_map'])

# %%
print (sample_data['doc_key'])
# Out:
# pilot/soc.culture.china_20050203.0639

# %%
sample_doc = []
for sentence in sample_data['sentences']:
    sample_doc.extend(sentence)

# %%
for mention in sample_data['mentions']:
    span_start, span_end, _, _  =  mention
    print(sample_doc[span_start: span_end + 1])
        
    print()
# Out:
# ['election']
#
# ['election']
#
# ['l', '##tle', '##e', '##1']
#
# ['election']
#
# ['election']
#
# ['Sunni', '##s']
#
# ['say']
#
# ['Iraq']
#
# ['poll']
#
# ['illegitimate']
#
# ['requirements']
#
# ['election']
#
# ['considered']
#
# ['election']
#
# ['Iraq']
#
# ['election']
#
# ['boycott']
#
# ['Sunni', '##s']
#
# ['20']
#
# ['population']
#
# ['city']
#
# ['200', ',', '000']
#
# ['1400']
#
# ['caste', '##d']
#
# ['their']
#
# ['votes']
#
# ['1400']
#
# ['workers']
#
# ['police', '##s']
#
# ['Shi', '##ites']
#
# ['south']
#
# ['Fall', '##u', '##jah']
#
# ['stations']
#
# ['vote']
#
# ['caste', '##d']
#
# ['their']
#
# ['boycott']
#
# ['reasonable']
#
# ['that']
#
# ['affect']
#
# ['legitimacy']
#
# ['election']
#
# ['Sunni', '##s']
#
# ['say']
#
# ['Iraq']
#
# ['poll']
#
# ['illegitimate']
#
# ['group']
#
# ['Iraqi']
#
# ['Sunni']
#
# ['c', '##ler', '##ics']
#
# ['said']
#
# ['country', "'", 's']
#
# ['election']
#
# ['legitimacy']
#
# ['Sunni', '##s']
#
# ['take']
#
# ...
